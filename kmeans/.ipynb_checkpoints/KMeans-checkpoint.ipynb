# %%
import seaborn as sns
from sklearn.datasets import make_blobs
import numpy as np
from numpy.random import uniform
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import random
import time
import math
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %%
centros = 5;
X_train, cats = make_blobs(n_samples = 100, centers = centros, random_state=45)
X_train = StandardScaler().fit_transform(X_train)

sns.scatterplot(x=[point[0] for point in X_train], y=[point[1] for point in X_train], hue=cats, palette='tab10')
plt.show()

# %%
def euclid(point, data):
    return np.sqrt(np.sum((point - data)**2, axis=1))

# %%
class KMeans:
    def __init__(self, k, max_iter=500):
        self.k = k
        self.max_iter = max_iter
        self.variancia_total = 10000
        self.melhor_variancia = float('inf')
        

    def fit(self, X_train, show=False):
        min, max = np.min(X_train, axis=0), np.max(X_train, axis=0)
        self.centroides = X_train[np.random.choice(range(len(X_train)), self.k)]
        
        prev_centroides = None

        iter = 0

        

        while np.not_equal(self.centroides, prev_centroides).any() and iter < self.max_iter:
            pontos_agrupados = [[] for _ in range(self.k)]

            for ponto in X_train:
                dists = euclid(ponto, self.centroides)
                centroide_proximo = np.argmin(dists)
                pontos_agrupados[centroide_proximo].append(ponto)

            prev_centroides = self.centroides
            self.centroides = [np.mean(cluster, axis=0) for cluster in pontos_agrupados]

            for i, centroide in enumerate(self.centroides):
                if np.isnan(centroide).any():
                    self.centroides[i] = prev_centroides[i]

            

            iter += 1

            
            if show:
                classe_centroides, classificacao = kmeans.evaluate(X_train)
                sns.scatterplot(x=[point[0] for point in X_train], y=[point[1] for point in X_train], hue=classificacao, palette='tab10')
                plt.plot([x for x, _ in kmeans.centroides], [y for _, y in kmeans.centroides], '+', markersize=10)
                plt.title("iter: " + str(iter) + ", var: " + str(self.variancia_total))
                plt.show()
       

            

    def evaluate(self, X):
        centroides = []
        centroide_ids = []
        variancias = [0 for _ in range(self.k)]
        elementos_por_classe = [-1 for _ in range(self.k)]
        for ponto in X:
            dists = euclid(ponto, self.centroides)
            centroide_id = np.argmin(dists)

            
            squared_distance = min(dists) ** 2
            variancias[centroide_id] += squared_distance
            
            elementos_por_classe[centroide_id] += 1
            
            centroides.append(self.centroides[centroide_id])
            centroide_ids.append(centroide_id)

        self.variancia_total = 0;
        
        for i in range(self.k):
            
            variancias[i] /= elementos_por_classe[i]
            variancias[i] = math.sqrt(variancias[i])
            self.variancia_total += variancias[i]

        

        return centroides, centroide_ids

    def best(self, X_train, show=False):
        centroides=[]
        variancias_totais=[]
        self.melhores_centroides = None
        
        
        for i in range(10):
            
            kmeans.fit(X_train)
            centroides.append(kmeans.centroides)
            variancias_totais.append(kmeans.variancia_total)
            if show:
                classe_centroides, classificacao = kmeans.evaluate(X_train)
                sns.scatterplot(x=[point[0] for point in X_train], y=[point[1] for point in X_train], hue=classificacao, palette='tab10')
                plt.plot([x for x, _ in kmeans.centroides], [y for _, y in kmeans.centroides], '+', markersize=10)
                plt.title("iter: " + str(i) + ", var: " + str(variancias_totais[i]))
                plt.show()
            #print("Variancia: ", variancias_totais[i])
            if(variancias_totais[i] < self.melhor_variancia):
                print("MELHORRRRRRRR")
                self.melhor_variancia = variancias_totais[i]
                self.melhores_centroides = centroides[i]

# %%
kmeans = KMeans(k=5)
kmeans.fit(X_train, show=True)

# %%
kmeans.best(X_train, show=True)
# Out:
# MELHORRRRRRRR
# MELHORRRRRRRR
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
kmeans.centroides = kmeans.melhores_centroides
classe_centroides, classificacao = kmeans.evaluate(X_train)
sns.scatterplot(x=[point[0] for point in X_train], y=[point[1] for point in X_train], hue=classificacao, palette='tab10')
plt.plot([x for x, _ in kmeans.centroides], [y for _, y in kmeans.centroides], '+', markersize=10)
plt.title("Melhor variancia " + str(kmeans.melhor_variancia))
plt.show()

# %%
ks = []
vars = []
for i in range(2, 10):
    kmeans.k = i
    kmeans.melhor_variancia = float('inf')
    kmeans.fit(X_train)
    #kmeans.best(X_train, show=True)
    kmeans.best(X_train)
    print(kmeans.melhores_centroides)
    #print(kmeans.melhor_variancia)
    kmeans.centroides = kmeans.melhores_centroides
    classe_centroides, classificacao = kmeans.evaluate(X_train)
    sns.scatterplot(x=[point[0] for point in X_train], y=[point[1] for point in X_train], hue=classificacao, palette='tab10')
    plt.plot([x for x, _ in kmeans.centroides], [y for _, y in kmeans.centroides], '+', markersize=10)
    plt.title("k: "+ str(i) + " variancia: " + str(kmeans.melhor_variancia))
    plt.show()

    ks.append(i)
    vars.append(kmeans.melhor_variancia)

plt.plot(ks, vars)
plot.show()
# Out:
# MELHORRRRRRRR
# [array([1.80702729, 0.77960005]), array([-0.45175682, -0.19490001])]
# MELHORRRRRRRR
# [array([1.80702729, 0.77960005]), array([-0.2938827 ,  0.75166066]), array([-0.60963095, -1.14146069])]
# MELHORRRRRRRR
# [array([-0.2938827 ,  0.75166066]), array([1.80702729, 0.77960005]), array([-0.26162352, -1.35930037]), array([-0.95763837, -0.923621  ])]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# MELHORRRRRRRR
# [array([1.08457191, 0.55724325]), array([-0.68451838,  1.08871422]), array([-1.1298471 , -1.21080058]), array([-0.92724859, -0.87294226]), array([-0.26162352, -1.35930037])]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# MELHORRRRRRRR
# [array([-0.2483302 , -1.58973059]), array([-0.95763837, -0.923621  ]), array([1.80702729, 0.77960005]), array([-0.78864686,  1.13303187]), array([-0.26878147, -1.23522255]), array([0.20088146, 0.37028945])]
# MELHORRRRRRRR
# [array([-0.92724859, -0.87294226]), array([1.80702729, 0.77960005]), array([-0.2483302 , -1.58973059]), array([-0.26878147, -1.23522255]), array([-1.1298471 , -1.21080058]), array([0.20088146, 0.37028945]), array([-0.78864686,  1.13303187])]
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# MELHORRRRRRRR
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# [array([-0.60963095, -1.14146069]), array([2.22965176, 0.39022013]), array([1.8050045 , 0.48028858]), array([-0.78864686,  1.13303187]), array([0.15968571, 0.56820392]), array([0.25123183, 0.12839399]), array([1.80600238, 0.95174859]), array([1.73930947, 0.70723821])]
# /var/folders/gy/4d1c9vqd21v6l_rtsrj3rtv40000gn/T/ipykernel_64737/278357762.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   variancias[i] /= elementos_por_classe[i]
# None
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[343], line 12
#      10 #print(kmeans.melhor_variancia)
#      11 kmeans.centroides = kmeans.melhores_centroides
# ---> 12 classe_centroides, classificacao = kmeans.evaluate(X_train)
#      13 sns.scatterplot(x=[point[0] for point in X_train], y=[point[1] for point in X_train], hue=classificacao, palette='tab10')
#      14 plt.plot([x for x, _ in kmeans.centroides], [y for _, y in kmeans.centroides], '+', markersize=10)
#
# Cell In[339], line 55, in KMeans.evaluate(self, X)
#      53 elementos_por_classe = [-1 for _ in range(self.k)]
#      54 for ponto in X:
# ---> 55     dists = euclid(ponto, self.centroides)
#      56     centroide_id = np.argmin(dists)
#      59     squared_distance = min(dists) ** 2
#
# Cell In[338], line 2, in euclid(point, data)
#       1 def euclid(point, data):
# ----> 2     return np.sqrt(np.sum((point - data)**2, axis=1))
#
# TypeError: unsupported operand type(s) for -: 'float' and 'NoneType'
